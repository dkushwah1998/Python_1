# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")    
import os

# %%
df = pd.read_csv("C:/Users/HP/Desktop/Python 1/Day 8 - Demos/IBM.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
f,ax = plt.subplots(figsize = (18,8))
sns.lineplot(x = 'JobRole',y='MonthlyIncome', data = df, ax = ax)
# Out:
# <AxesSubplot:xlabel='JobRole', ylabel='MonthlyIncome'>

# %%
f,ax = plt.subplots(figsize = (18,8))
sns.lineplot(x = 'JobRole',y='MonthlyIncome', data = df, ax = ax).set(
    xlabel = 'Job Role', ylabel = 'Monthly Inscome', title = "Line Plot - Job Role Vs Monthly Income")
# Out:
# [Text(0.5, 0, 'Job Role'),
#  Text(0, 0.5, 'Monthly Inscome'),
#  Text(0.5, 1.0, 'Line Plot - Job Role Vs Monthly Income')]

# %%
f,ax = plt.subplots(figsize = (18,8))
sns.lineplot(x = 'JobRole',y='MonthlyIncome',hue = 'Gender',err_style = 'bars', data = df, ax = ax).set(
    xlabel = 'Job Role', ylabel = 'Monthly Inscome', title = "Line Plot - Job Role Vs Monthly Income")
# Out:
# [Text(0.5, 0, 'Job Role'),
#  Text(0, 0.5, 'Monthly Inscome'),
#  Text(0.5, 1.0, 'Line Plot - Job Role Vs Monthly Income')]

# %%
sns.barplot(x = 'Attrition', y = "MonthlyIncome", data = df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
f,ax = plt.subplots()
new_df = df["Gender"].groupby(df["Attrition"]).value_counts(normalize = True).rename("Percentage of group").reset_index()

sns.barplot(x = "Attrition",y = "Percentage of group",hue ='Gender', data = new_df)
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
ax.set(title = 'Distribution of gender')
# Out:
# [Text(0.5, 1.0, 'Distribution of gender')]

# %%
sns.barplot(df['Gender'],df['DistanceFromHome'],hue = df['Attrition'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='DistanceFromHome'>

# %%
sns.scatterplot(x=df['MonthlyIncome'],y=df['YearsAtCompany'],hue=df['Attrition'])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='YearsAtCompany'>

# %%
sns.distplot(df['Age'], kde = False)
plt.ylabel('No. of Observations')
# Out:
# Text(0, 0.5, 'No. of Observations')

# %%
sns.distplot(df['MonthlyIncome'], kde = False) 
plt.ylabel('No. of Observations')
# Out:
# Text(0, 0.5, 'No. of Observations')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Department",y="MonthlyIncome",data=df,palette="Set2")
# Out:
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %%
labels=df.JobRole.value_counts().index
colors=["olive","orange","hotpink","slateblue","y","lime"]
sizes=df.JobRole.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%")
plt.title("Percentage of Research Scientists",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of Research Scientists')

# %%
labels=df.JobRole.value_counts().index
colors=["olive","orange","hotpink","slateblue","y","lime"]
explode=[0,0.2,0,0,0,0,0,0,0]
sizes=df.JobRole.value_counts().values
plt.figure(figsize=(7,7))
plt.pie(sizes,labels=labels,colors=colors,autopct="%1.1f%%",explode=explode)
plt.title("Percentage of Research Scientists",color="saddlebrown",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percentage of Research Scientists')

# %%
f,ax=plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt=".1f",ax=ax)
# Out:
# <AxesSubplot:>

# %%
Imp_features=['YearsWithCurrManager','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole']
sns.heatmap(df[Imp_features].corr(),annot=True,linewidths=0.5,linecolor="black",fmt=".1f")
plt.show()
