# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
df = df.pivot('month','year','passengers')
sns.heatmap(df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
cmap = 'tab20'
sns.heatmap(df,cmap=cmap)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(df, annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
linewidths = 2
linecolor = "pink"
sns.heatmap(data=df,linewidths=linewidths,linecolor=linecolor)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
linewidths = 2
linecolor = "pink"
sns.heatmap(data=df,linewidths=linewidths,linecolor=linecolor,annot =True, fmt ='d')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
cmap = 'tab20'
linewidths = 2
linecolor = "pink"
sns.heatmap(data=df,linewidths=linewidths,linecolor=linecolor,annot =True, fmt ='d',cmap=cmap)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# # 3

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.scatterplot(data = df, x= 'sepal_length', y='petal_length', hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x = "sepal_width", y='petal_width', data = df, style='species', hue = 'species')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=df, hue='species', palette='pastel')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot( x = 'petal_length', y='species', data = df, legend='brief')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.scatterplot(x='sepal_length', y='species', data=df, alpha = 0.3)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>
